# %%
import json
import numpy as np
from sentence_transformers import SentenceTransformer
import os

# 1. Configuration
INPUT_FILE = 'wiki_math_knowledge_base_api.json'
MODEL_NAME = 'mixedbread-ai/mxbai-embed-large-v1'
OUTPUT_MATRIX_FILE = 'embeddings_matrix.npy'
# OUTPUT_MODEL_DIR = 'saved_mxbai_model_weights'

def main():
    # 2. Load the content from the JSON file
    print(f"Loading data from {INPUT_FILE}...")
    try:
        with open(INPUT_FILE, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: File {INPUT_FILE} not found. Please ensure the file is in the same directory.")
        return

    # Extract the raw text from each chunk
    # We verify 'raw_text' exists to avoid errors
    texts = [item['raw_text'] for item in data if 'raw_text' in item]
    print(f"Found {len(texts)} text chunks to embed.")

    # 3. Load the Embedding Model
    print(f"Loading model: {MODEL_NAME}...")
    # This automatically downloads the model weights from Hugging Face
    model = SentenceTransformer(MODEL_NAME)

    # 4. Generate Embeddings
    print("Generating embeddings (this may take a moment depending on your hardware)...")
    # For mxbai-embed-large-v1, documents (which these are) generally do not require 
    # the specific query prompt ("Represent this sentence...") that user queries do.
    embeddings = model.encode(texts, show_progress_bar=True)

    # 5. Save the Embedding Matrix
    print(f"Saving embedding matrix to {OUTPUT_MATRIX_FILE}...")
    # Saves as a binary NumPy file (.npy)
    np.save(OUTPUT_MATRIX_FILE, embeddings)
    print(f"Matrix shape: {embeddings.shape}")

    # 6. Save the Model Weights
    # print(f"Saving model weights to {OUTPUT_MODEL_DIR}...")
    # model.save(OUTPUT_MODEL_DIR)
    
    print("\nDone! You now have:")
    print(f"1. The embedding matrix: {os.path.abspath(OUTPUT_MATRIX_FILE)}")
    print(f"2. The model weights: {os.path.abspath(OUTPUT_MODEL_DIR)}")

if __name__ == "__main__":
    main()
# Out:
# Loading data from wiki_math_knowledge_base_api.json...
# Found 2041 text chunks to embed.
# Loading model: mixedbread-ai/mxbai-embed-large-v1...
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# Generating embeddings (this may take a moment depending on your hardware)...
# Batches:   0%|          | 0/64 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 53
#      50     print(f"2. The model weights: {os.path.abspath(OUTPUT_MODEL_DIR)}")
#      52 if __name__ == "__main__":
# ---> 53     main()
#
# Cell In[1], line 36, in main()
#      33 print("Generating embeddings (this may take a moment depending on your hardware)...")
#      34 # For mxbai-embed-large-v1, documents (which these are) generally do not require
#      35 # the specific query prompt ("Represent this sentence...") that user queries do.
# ---> 36 embeddings = model.encode(texts, show_progress_bar=True)
#      38 # 5. Save the Embedding Matrix
#      39 print(f"Saving embedding matrix to {OUTPUT_MATRIX_FILE}...")
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\sentence_transformers\models\Transformer.py:262, in Transformer.forward(self, features, **kwargs)
#     239 """
#     240 Forward pass through the transformer model.
#     241
#    (...)    258         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     259 """
#     260 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 262 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     263 token_embeddings = outputs[0]
#     264 features["token_embeddings"] = token_embeddings
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\transformers\utils\generic.py:1002, in check_model_inputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#    1000             outputs = func(self, *args, **kwargs)
#    1001     else:
# -> 1002         outputs = func(self, *args, **kwargs)
#    1003 except TypeError as original_exception:
#    1004     # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#    1005     # Get a TypeError even after removing the recordable kwargs -> re-raise the original exception
#    1006     # Otherwise -> we're probably missing `**kwargs` in the decorated function
#    1007     kwargs_without_recordable = {k: v for k, v in kwargs.items() if k not in recordable_keys}
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\transformers\models\bert\modeling_bert.py:696, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     679 embedding_output = self.embeddings(
#     680     input_ids=input_ids,
#     681     position_ids=position_ids,
#    (...)    684     past_key_values_length=past_key_values_length,
#     685 )
#     687 attention_mask, encoder_attention_mask = self._create_attention_masks(
#     688     attention_mask=attention_mask,
#     689     encoder_attention_mask=encoder_attention_mask,
#    (...)    693     past_key_values=past_key_values,
#     694 )
# --> 696 encoder_outputs = self.encoder(
#     697     embedding_output,
#     698     attention_mask=attention_mask,
#     699     encoder_hidden_states=encoder_hidden_states,
#     700     encoder_attention_mask=encoder_attention_mask,
#     701     past_key_values=past_key_values,
#     702     use_cache=use_cache,
#     703     cache_position=cache_position,
#     704     position_ids=position_ids,
#     705     **kwargs,
#     706 )
#     707 sequence_output = encoder_outputs.last_hidden_state
#     708 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\transformers\models\bert\modeling_bert.py:452, in BertEncoder.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, cache_position, **kwargs)
#     440 def forward(
#     441     self,
#     442     hidden_states: torch.Tensor,
#    (...)    449     **kwargs: Unpack[TransformersKwargs],
#     450 ) -> tuple[torch.Tensor] | BaseModelOutputWithPastAndCrossAttentions:
#     451     for i, layer_module in enumerate(self.layer):
# --> 452         hidden_states = layer_module(
#     453             hidden_states,
#     454             attention_mask,
#     455             encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     456             encoder_attention_mask=encoder_attention_mask,
#     457             past_key_values=past_key_values,
#     458             cache_position=cache_position,
#     459             **kwargs,
#     460         )
#     462     return BaseModelOutputWithPastAndCrossAttentions(
#     463         last_hidden_state=hidden_states,
#     464         past_key_values=past_key_values if use_cache else None,
#     465     )
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\transformers\modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\transformers\models\bert\modeling_bert.py:397, in BertLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     387 def forward(
#     388     self,
#     389     hidden_states: torch.Tensor,
#    (...)    395     **kwargs: Unpack[TransformersKwargs],
#     396 ) -> tuple[torch.Tensor]:
# --> 397     self_attention_output, _ = self.attention(
#     398         hidden_states,
#     399         attention_mask,
#     400         past_key_values=past_key_values,
#     401         cache_position=cache_position,
#     402         **kwargs,
#     403     )
#     404     attention_output = self_attention_output
#     406     if self.is_decoder and encoder_hidden_states is not None:
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\transformers\models\bert\modeling_bert.py:326, in BertAttention.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, cache_position, **kwargs)
#     315 def forward(
#     316     self,
#     317     hidden_states: torch.Tensor,
#    (...)    323     **kwargs: Unpack[TransformersKwargs],
#     324 ) -> tuple[torch.Tensor]:
#     325     attention_mask = attention_mask if not self.is_cross_attention else encoder_attention_mask
# --> 326     attention_output, attn_weights = self.self(
#     327         hidden_states,
#     328         encoder_hidden_states=encoder_hidden_states,
#     329         attention_mask=attention_mask,
#     330         past_key_values=past_key_values,
#     331         cache_position=cache_position,
#     332         **kwargs,
#     333     )
#     334     attention_output = self.output(attention_output, hidden_states)
#     335     return attention_output, attn_weights
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\transformers\models\bert\modeling_bert.py:180, in BertSelfAttention.forward(self, hidden_states, attention_mask, past_key_values, cache_position, **kwargs)
#     177 hidden_shape = (*input_shape, -1, self.attention_head_size)
#     179 # get all proj
# --> 180 query_layer = self.query(hidden_states).view(*hidden_shape).transpose(1, 2)
#     181 key_layer = self.key(hidden_states).view(*hidden_shape).transpose(1, 2)
#     182 value_layer = self.value(hidden_states).view(*hidden_shape).transpose(1, 2)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\SWI2026\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
