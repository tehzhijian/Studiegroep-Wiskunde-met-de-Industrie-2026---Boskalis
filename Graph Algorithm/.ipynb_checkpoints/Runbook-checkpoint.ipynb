# %%
import os
import json
import logging
import networkx as nx
import transformers
from builder import CausalGraphBuilder

# %%
# 1. FIX: Suppress the "UNEXPECTED" model loading warning
# This tells the transformers library to ignore non-critical weight mismatches
transformers.logging.set_verbosity_error()

# 2. Setup standard logging for your application
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# 3. Load the Input Data
input_file = 'wiki_knowledge_base_api.json'
documents = []

# %%
try:
    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        # Extract 'raw_text' from the JSON structure
        documents = [item.get('raw_text', '') for item in data if item.get('raw_text')]
    
    logger.info(f"Loaded {len(documents)} text chunks from {input_file}")

except FileNotFoundError:
    logger.error(f"File {input_file} not found. Please check the path.")
    documents = []

# 4. Initialize Builder with Rule-Based Extraction
# Note: You will still see the "Unauthenticated requests" warning unless you set os.environ["HF_TOKEN"]
# This is harmless and just means the download might be slightly slower.
builder = CausalGraphBuilder(
    model_name="all-roberta-large-v1",
    extractor_method="rule", 
    confidence_threshold=0.6,
    normalize_nodes=True
)
# Out:
# 2026-01-27 15:54:30,819 - INFO - Loaded 1343 text chunks from wiki_knowledge_base_api.json
# 2026-01-27 15:54:30,827 - INFO - Use pytorch device_name: cpu
# 2026-01-27 15:54:30,831 - INFO - Load pretrained SentenceTransformer: all-roberta-large-v1
# 2026-01-27 15:54:30,994 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:54:31,006 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/modules.json "HTTP/1.1 200 OK"
# 2026-01-27 15:54:31,027 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/modules.json "HTTP/1.1 200 OK"
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\Teh Zhi Jian\anaconda3\envs\SWI2026\Lib\site-packages\huggingface_hub\file_download.py:130: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Teh Zhi Jian\.cache\huggingface\hub\models--sentence-transformers--all-roberta-large-v1. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# 2026-01-27 15:54:31,144 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:54:31,159 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-01-27 15:54:31,201 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/config_sentence_transformers.json "HTTP/1.1 200 OK"
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# 2026-01-27 15:54:31,317 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:54:31,326 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-01-27 15:54:31,433 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:54:31,443 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/README.md "HTTP/1.1 200 OK"
# 2026-01-27 15:54:31,460 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/README.md "HTTP/1.1 200 OK"
# README.md: 0.00B [00:00, ?B/s]
# 2026-01-27 15:54:31,621 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:54:31,637 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/modules.json "HTTP/1.1 200 OK"
# 2026-01-27 15:54:31,747 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:54:31,758 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/sentence_bert_config.json "HTTP/1.1 200 OK"
# 2026-01-27 15:54:31,772 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/sentence_bert_config.json "HTTP/1.1 200 OK"
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# 2026-01-27 15:54:31,905 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-01-27 15:54:32,009 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:54:32,023 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/config.json "HTTP/1.1 200 OK"
# 2026-01-27 15:54:32,043 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/config.json "HTTP/1.1 200 OK"
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# 2026-01-27 15:54:32,274 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# 2026-01-27 15:54:32,379 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-roberta-large-v1/xet-read-token/cf74d8acd4f198de950bf004b262e6accfed5d2c "HTTP/1.1 200 OK"
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# 2026-01-27 15:55:42,917 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:55:42,926 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/config.json "HTTP/1.1 200 OK"
# 2026-01-27 15:55:43,031 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:55:43,039 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-01-27 15:55:43,059 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json:   0%|          | 0.00/328 [00:00<?, ?B/s]
# 2026-01-27 15:55:43,214 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-roberta-large-v1/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-01-27 15:55:43,322 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-roberta-large-v1/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-01-27 15:55:43,452 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:55:43,460 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/vocab.json "HTTP/1.1 200 OK"
# 2026-01-27 15:55:43,472 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/vocab.json "HTTP/1.1 200 OK"
# vocab.json: 0.00B [00:00, ?B/s]
# 2026-01-27 15:55:43,671 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:55:43,681 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/merges.txt "HTTP/1.1 200 OK"
# 2026-01-27 15:55:43,693 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/merges.txt "HTTP/1.1 200 OK"
# merges.txt: 0.00B [00:00, ?B/s]
# 2026-01-27 15:55:43,832 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:55:43,843 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/tokenizer.json "HTTP/1.1 200 OK"
# 2026-01-27 15:55:43,862 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/tokenizer.json "HTTP/1.1 200 OK"
# tokenizer.json: 0.00B [00:00, ?B/s]
# 2026-01-27 15:55:44,007 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/added_tokens.json "HTTP/1.1 404 Not Found"
# 2026-01-27 15:55:44,122 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:55:44,132 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/special_tokens_map.json "HTTP/1.1 200 OK"
# 2026-01-27 15:55:44,142 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/special_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 2026-01-27 15:55:44,260 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# 2026-01-27 15:55:44,664 - INFO - HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-roberta-large-v1/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-01-27 15:55:44,672 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 2026-01-27 15:55:44,692 - INFO - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-roberta-large-v1/cf74d8acd4f198de950bf004b262e6accfed5d2c/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# 2026-01-27 15:55:44,813 - INFO - HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-roberta-large-v1 "HTTP/1.1 200 OK"

# %%
if documents:
    # 4. Index Documents
    logger.info("Building graph...")
    builder.index_documents(documents, batch_size=50, show_progress=True)

    # 5. Save for Reuse (The Important Part)
    
    # --- Format A: Native Builder JSON (Best for Python Reuse) ---
    # This preserves the builder's internal mapping of text variants to node IDs.
    # You can reload this later using builder.load("causal_graph.json")
    builder.save("causal_graph_state.json")
    logger.info("Saved reusable state to 'causal_graph_state.json'")

    # --- Format B: GraphML (Best for External Analysis) ---
    # This standard format can be opened in Gephi, Cytoscape, or other graph tools.
    G = builder.get_graph()
    nx.write_graphml(G, "causal_graph.graphml")
    logger.info("Saved network structure to 'causal_graph.graphml'")
    
    # 6. (Optional) Quick Statistics check
    print(f"Graph constructed with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")

else:
    logger.warning("No documents to process.")
# Out:
# 2026-01-27 15:56:56,520 - INFO - Building graph...
# Building causal graph:   0%|                                                                  | 0/1343 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-27 15:56:59,653 - INFO - Processed batch 5/27: found 0 causal relationships
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-27 15:57:10,874 - INFO - Processed batch 10/27: found 0 causal relationships
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-27 15:57:15,283 - INFO - Processed batch 15/27: found 1 causal relationships
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-27 15:57:17,460 - INFO - Processed batch 20/27: found 1 causal relationships
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-27 15:57:22,518 - INFO - Processed batch 25/27: found 1 causal relationships
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-01-27 15:57:23,908 - INFO - Processed batch 27/27: found 5 causal relationships
# 2026-01-27 15:57:23,909 - INFO - Indexing complete: 1343 documents processed
# 2026-01-27 15:57:23,910 - INFO - Added 96 new nodes and 51 new relationships to graph
# 2026-01-27 15:57:23,910 - INFO - Graph now has 96 nodes and 51 edges
# Building causal graph:   0%|                                                                  | 0/1343 [00:27<?, ?it/s]
# 2026-01-27 15:57:23,916 - INFO - Saved reusable state to 'causal_graph_state.json'
# 2026-01-27 15:57:23,921 - INFO - Saved network structure to 'causal_graph.graphml'
# Graph constructed with 96 nodes and 51 edges.

# %%
# This will reconstruct the graph structure and re-generate embeddings for the nodes
success = builder.load("causal_graph_state.json")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Graph loaded successfully!
# Nodes: 96
# Edges: 51

# %%
if success:
    print("Graph loaded successfully!")
    
    # 3. Verify it loaded by printing some stats
    stats = builder.get_extraction_statistics()
    print(f"Nodes: {stats['graph_statistics']['nodes']}")
    print(f"Edges: {stats['graph_statistics']['edges']}")
    
    # 4. (Optional) Visualize it again to make sure it looks right
    # builder.visualize_graph("reloaded_graph.html")
else:
    print("Failed to load graph.")
# Out:
# Graph loaded successfully!
# Nodes: 96
# Edges: 51

# %%
# Export to GraphML format
G = builder.get_graph()
nx.write_graphml(G, "causal_graph.graphml")
print("Exported to causal_graph.graphml")
# Out:
# Exported to causal_graph.graphml

# %%
import matplotlib.pyplot as plt

# Get the graph object
G = builder.get_graph()

# Setup the plot
plt.figure(figsize=(12, 20))
pos = nx.spring_layout(G, k=0.5)  # k regulates the distance between nodes

# Draw the graph
nx.draw(G, pos, 
        with_labels=True, 
        node_color='lightblue', 
        node_size=500, 
        font_size=8, 
        arrows=True)

plt.title("Causal Graph Visualization")
plt.show()
